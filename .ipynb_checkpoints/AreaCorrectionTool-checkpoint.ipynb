# %%
import sys
import os

import numpy as np
import difflib
import pandas as pd
import glob
from tifffile import imread, imwrite



from Utils.helpers import Prob_to_Binary, zero_pad_color, multiplot,WingArea, multiplotline
import tifffile
import napari
try:
    from pathlib import Path
    Path().expanduser()
except (ImportError,AttributeError):
    from pathlib2 import Path

# %%
Masterdir = 'C:/Users/Users/ImagesForFAQT/Eip_cte29/'



MaskResults = Masterdir + '/MaskResults/'
OverlayResults = MaskResults + '/Overlays/'
AreaResults = Masterdir + '/AreaResults/'
AreaResultsName = 'Area'

# %%
Raw_path = os.path.join(Masterdir, '*tif')
Left_path = os.path.join(MaskResults, '*tif')
filesRaw = glob.glob(Raw_path)
filesRaw.sort
filesLeft = glob.glob(Left_path)
filesLeft.sort
for secondname in filesLeft:
    image = imread(secondname)
    if len(image.shape) == 3:
       image = image[:,:,0]
    Name = os.path.basename(os.path.splitext(secondname)[0])
    imwrite((MaskResults + Name + '.tif' ) , image.astype('uint16'))

# %%
axes = 'YX'
saveaxes = 'YX'
Path(OverlayResults).mkdir(exist_ok = True)
RawImages = []
LeftImages = []
Name = []
AllArea = []
for fname in filesRaw:
  for secondname in filesLeft:
    if os.path.basename(os.path.splitext(secondname)[0]) == 'Mask' + os.path.basename(os.path.splitext(fname)[0]):
            image = imread(fname)
            
            Leftimage = imread(secondname)
            RawImages.append(image)
            LeftImages.append(Leftimage)
            Name.append(os.path.basename(os.path.splitext(fname)[0]))
           
with napari.gui_qt():
   
    # initialise viewer with Left wing image
    viewer = napari.view_image(np.asarray(RawImages), name='Wings', rgb=True)

    # add the labels
    label_layer = viewer.add_labels(np.asarray(LeftImages), name='segmentation')  
    
    
   
ModifiedArray = viewer.layers['segmentation'].data 

for i in range(0, ModifiedArray.shape[0]):
    
     imwrite((MaskResults + 'Mask' + Name[i] + '.tif' ) , ModifiedArray[i].astype('uint8'))

# %%
import pandas as pd
Path(AreaResults).mkdir(exist_ok = True)
Maskpath = os.path.join(MaskResults, '*tif')


filesRaw = glob.glob(Maskpath)



AllArea = []


AllName = []
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 150)
for fnameRight in filesRaw:
    
           NameRight = os.path.basename(os.path.splitext(fnameRight)[0]) 
           imageRight = imread(fnameRight)
           Area, _, _, _, _ = WingArea(imageRight, imageRight)
           AllName.append(NameRight)
           AllArea.append(Area)
            
df = pd.DataFrame(list(zip(AllArea)), index =AllName, 
                                              columns =['Area'])

df.to_csv(AreaResults + '/' + AreaResultsName +  '.csv')  
df
# Out:
#                                          Area
# MaskEip_d8iTrip_cte29_OV-of-09.10_L00  187787
# MaskEip_d8iTrip_cte29_OV-of-09.10_L01  190547
# MaskEip_d8iTrip_cte29_OV-of-09.10_L02  146190
# MaskEip_d8iTrip_cte29_OV-of-09.10_L03  193512
# MaskEip_d8iTrip_cte29_OV-of-09.10_L04  199110
# MaskEip_d8iTrip_cte29_OV-of-09.10_L05  192370
# MaskEip_d8iTrip_cte29_OV-of-09.10_L06  191236
# MaskEip_d8iTrip_cte29_OV-of-09.10_L07  199278
# MaskEip_d8iTrip_cte29_OV-of-09.10_L08  187990
# MaskEip_d8iTrip_cte29_OV-of-09.10_L09  213217
# MaskEip_d8iTrip_cte29_OV-of-09.10_L10  184260
# MaskEip_d8iTrip_cte29_OV-of-09.10_L11  204134
# MaskEip_d8iTrip_cte29_OV-of-09.10_L12  206346
# MaskEip_d8iTrip_cte29_OV-of-09.10_L13  215267
# MaskEip_d8iTrip_cte29_OV-of-09.10_L14  201710
# MaskEip_d8iTrip_cte29_OV-of-09.10_L15  178212
# MaskEip_d8iTrip_cte29_OV-of-09.10_L16  161053
# MaskEip_d8iTrip_cte29_OV-of-09.10_L17  162245
# MaskEip_d8iTrip_cte29_OV-of-09.10_L18  180229
# MaskEip_d8iTrip_cte29_OV-of-09.10_L19  215646
# MaskEip_d8iTrip_cte29_OV-of-09.10_L20  165685
# MaskEip_d8iTrip_cte29_OV-of-09.10_L21  191692
# MaskEip_d8iTrip_cte29_OV-of-09.10_L22  184566
# MaskEip_d8iTrip_cte29_OV-of-09.10_L23  183415
# MaskEip_d8iTrip_cte29_OV-of-09.10_L24  198379
# MaskEip_d8iTrip_cte29_OV-of-09.10_L25  197007
# MaskEip_d8iTrip_cte29_OV-of-09.10_L26  184204
# MaskEip_d8iTrip_cte29_OV-of-09.10_L27  142149
# MaskEip_d8iTrip_cte29_OV-of-09.10_L28  179498
# MaskEip_d8iTrip_cte29_OV-of-09.10_L29  217700
# MaskEip_d8iTrip_cte29_OV-of-09.10_L30  192593
# MaskEip_d8iTrip_cte29_OV-of-09.10_L31  201293
# MaskEip_d8iTrip_cte29_OV-of-09.10_R00  189686
# MaskEip_d8iTrip_cte29_OV-of-09.10_R01  189410
# MaskEip_d8iTrip_cte29_OV-of-09.10_R02  143336
# MaskEip_d8iTrip_cte29_OV-of-09.10_R03  193027
# MaskEip_d8iTrip_cte29_OV-of-09.10_R04  203278
# MaskEip_d8iTrip_cte29_OV-of-09.10_R05  190605
# MaskEip_d8iTrip_cte29_OV-of-09.10_R06  187615
# MaskEip_d8iTrip_cte29_OV-of-09.10_R07  191776
# MaskEip_d8iTrip_cte29_OV-of-09.10_R08  178973
# MaskEip_d8iTrip_cte29_OV-of-09.10_R09  212103
# MaskEip_d8iTrip_cte29_OV-of-09.10_R10  178191
# MaskEip_d8iTrip_cte29_OV-of-09.10_R11  202528
# MaskEip_d8iTrip_cte29_OV-of-09.10_R12  205056
# MaskEip_d8iTrip_cte29_OV-of-09.10_R13  213497
# MaskEip_d8iTrip_cte29_OV-of-09.10_R14  199997
# MaskEip_d8iTrip_cte29_OV-of-09.10_R15  173449
# MaskEip_d8iTrip_cte29_OV-of-09.10_R16  157678
# MaskEip_d8iTrip_cte29_OV-of-09.10_R17  155751
# MaskEip_d8iTrip_cte29_OV-of-09.10_R18  211171
# MaskEip_d8iTrip_cte29_OV-of-09.10_R19  219035
# MaskEip_d8iTrip_cte29_OV-of-09.10_R20  168351
# MaskEip_d8iTrip_cte29_OV-of-09.10_R21  184222
# MaskEip_d8iTrip_cte29_OV-of-09.10_R22  182643
# MaskEip_d8iTrip_cte29_OV-of-09.10_R23  178750
# MaskEip_d8iTrip_cte29_OV-of-09.10_R24  198736
# MaskEip_d8iTrip_cte29_OV-of-09.10_R25  195071
# MaskEip_d8iTrip_cte29_OV-of-09.10_R26  180177
# MaskEip_d8iTrip_cte29_OV-of-09.10_R27  138699
# MaskEip_d8iTrip_cte29_OV-of-09.10_R28  177849
# MaskEip_d8iTrip_cte29_OV-of-09.10_R29  216381
# MaskEip_d8iTrip_cte29_OV-of-09.10_R30  189295
# MaskEip_d8iTrip_cte29_OV-of-09.10_R31  201717
# MaskEip_w1118_cte29_OV-of-09.10_L00    237484
# MaskEip_w1118_cte29_OV-of-09.10_L01    200749
# MaskEip_w1118_cte29_OV-of-09.10_L02    207986
# MaskEip_w1118_cte29_OV-of-09.10_L03    209097
# MaskEip_w1118_cte29_OV-of-09.10_L04    235859
# MaskEip_w1118_cte29_OV-of-09.10_L05    225991
# MaskEip_w1118_cte29_OV-of-09.10_L06    199165
# MaskEip_w1118_cte29_OV-of-09.10_L07    206771
# MaskEip_w1118_cte29_OV-of-09.10_L08    214088
# MaskEip_w1118_cte29_OV-of-09.10_L09    235120
# MaskEip_w1118_cte29_OV-of-09.10_L10    220887
# MaskEip_w1118_cte29_OV-of-09.10_L11    230713
# MaskEip_w1118_cte29_OV-of-09.10_L12    228376
# MaskEip_w1118_cte29_OV-of-09.10_L13    220360
# MaskEip_w1118_cte29_OV-of-09.10_L14    232512
# MaskEip_w1118_cte29_OV-of-09.10_L15    214585
# MaskEip_w1118_cte29_OV-of-09.10_L16    203024
# MaskEip_w1118_cte29_OV-of-09.10_L17    223658
# MaskEip_w1118_cte29_OV-of-09.10_L18    202058
# MaskEip_w1118_cte29_OV-of-09.10_L19    232780
# MaskEip_w1118_cte29_OV-of-09.10_L20    226464
# MaskEip_w1118_cte29_OV-of-09.10_L21    234991
# MaskEip_w1118_cte29_OV-of-09.10_L22    225697
# MaskEip_w1118_cte29_OV-of-09.10_L23    207184
# MaskEip_w1118_cte29_OV-of-09.10_L24    218109
# MaskEip_w1118_cte29_OV-of-09.10_L25    223717
# MaskEip_w1118_cte29_OV-of-09.10_L26    182159
# MaskEip_w1118_cte29_OV-of-09.10_R00    234419
# MaskEip_w1118_cte29_OV-of-09.10_R01    198998
# MaskEip_w1118_cte29_OV-of-09.10_R02    207483
# MaskEip_w1118_cte29_OV-of-09.10_R03    207735
# MaskEip_w1118_cte29_OV-of-09.10_R04    229052
# MaskEip_w1118_cte29_OV-of-09.10_R05    224430
# MaskEip_w1118_cte29_OV-of-09.10_R06    197277
# MaskEip_w1118_cte29_OV-of-09.10_R07    210217
# MaskEip_w1118_cte29_OV-of-09.10_R08    211389
# MaskEip_w1118_cte29_OV-of-09.10_R09    232683
# MaskEip_w1118_cte29_OV-of-09.10_R10    218772
# MaskEip_w1118_cte29_OV-of-09.10_R11    225549
# MaskEip_w1118_cte29_OV-of-09.10_R12    222095
# MaskEip_w1118_cte29_OV-of-09.10_R13    222278
# MaskEip_w1118_cte29_OV-of-09.10_R14    227822
# MaskEip_w1118_cte29_OV-of-09.10_R15    213962
# MaskEip_w1118_cte29_OV-of-09.10_R16    199644
# MaskEip_w1118_cte29_OV-of-09.10_R17    221929
# MaskEip_w1118_cte29_OV-of-09.10_R18    191470
# MaskEip_w1118_cte29_OV-of-09.10_R19    233642
# MaskEip_w1118_cte29_OV-of-09.10_R20    222706
# MaskEip_w1118_cte29_OV-of-09.10_R21    235027
# MaskEip_w1118_cte29_OV-of-09.10_R22    221600
# MaskEip_w1118_cte29_OV-of-09.10_R23    205178
# MaskEip_w1118_cte29_OV-of-09.10_R24    213674
# MaskEip_w1118_cte29_OV-of-09.10_R25    222309
# MaskEip_w1118_cte29_OV-of-09.10_R26    179160
